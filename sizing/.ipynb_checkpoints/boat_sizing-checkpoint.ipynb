# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#### Inputs ####

## Mass ##
boat_empty_mass = 10.0 #kg
payload_mass = np.linspace(2.0, 30.0, 50) #kg

## MISC ##
water_density = 1000.0 # kg / m^3

# %%
#### Hull Volume Calculation ####
total_mass = boat_empty_mass + payload_mass
displaced_volume = total_mass / water_density
plt.plot(payload_mass, displaced_volume)
plt.xlabel(r'Payload Mass (kg)')
plt.ylabel(r'Hull Volume ($m^3$)')
plt.title(r'Hull Volume $(M_0 = ' + str(boat_empty_mass) + ')$')
plt.grid(1)
