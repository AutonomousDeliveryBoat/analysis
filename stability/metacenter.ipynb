# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
catamaran_aspect_ratio = 4.0
T = np.linspace(0.1, 0.2, 1000)

length = 0.5
b = 40.0 / (1000.0*length*T) / 2.0
print 4*b
# Out:
# [ 1.6         1.5984      1.5968032   1.59520958  1.59361914  1.59203187
#   1.59044776  1.5888668   1.58728898  1.58571429  1.58414272  1.58257426
#   1.5810089   1.57944664  1.57788746  1.57633136  1.57477833  1.57322835
#   1.57168142  1.57013752  1.56859666  1.56705882  1.565524    1.56399217
#   1.56246334  1.5609375   1.55941463  1.55789474  1.5563778   1.55486381
#   1.55335277  1.55184466  1.55033948  1.54883721  1.54733785  1.54584139
#   1.54434783  1.54285714  1.54136933  1.53988439  1.53840231  1.53692308
#   1.53544669  1.53397313  1.5325024   1.53103448  1.52956938  1.52810707
#   1.52664756  1.52519084  1.52373689  1.52228571  1.5208373   1.51939163
#   1.51794872  1.51650854  1.51507109  1.51363636  1.51220435  1.51077505
#   1.50934844  1.50792453  1.5065033   1.50508475  1.50366886  1.50225564
#   1.50084507  1.49943715  1.49803187  1.49662921  1.49522919  1.49383178
#   1.49243697  1.49104478  1.48965517  1.48826816  1.48688372  1.48550186
# ...

# %%
KM_cat = (catamaran_aspect_ratio - 1.0)**2/4.0 * b**2 / T
KM_mono = b**2/(3*T) + T/2.0

# %%
plt.xlabel('Draft (cm)')
plt.ylabel('Metacentric Height (m)')
plt.plot(T*100.0, KM_mono)
plt.plot(T*100.0, KM_cat)
plt.legend(['Monohull', 'Catamaran'])
plt.savefig('metacentric_height.png')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
